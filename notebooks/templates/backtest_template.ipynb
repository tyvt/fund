# %% [markdown]
# # VectorBT 回测研究模板

# %%
from pathlib import Path
import sys

start = Path.cwd().resolve()
ROOT = next((candidate for candidate in (start, *start.parents) if (candidate / 'vbt').exists()), start)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print(f'项目根目录: {ROOT}')

# %% [markdown]
# ## 研究假设
#
# 在这里记录参数变更的理由、预期影响和验收阈值。

# %% [markdown]
# ## 配置

# %%
from vbt.config import load_backtest_config, load_strategy_config
config = load_backtest_config()
params = load_strategy_config()
# 仅在这里覆盖参数，确保实验可复现：
overrides = {}
params.update(overrides)
config, params

# %% [markdown]
# ## 数据、回测与结果

# %%
# 参考 02_Single_Backtest.ipynb；完成实验后将报告归档到 output/vectorbt/。

# %% [markdown]
# ## 结论
#
# 记录是否接受参数变更，以及与基准的差异。
